# %% [markdown]
# # 데이터 병합 및 샘플링 실행 결과

# %% [markdown]
# **설명 파일 :** [02_데이터병합및샘플링.md](02_데이터병합및샘플링.md)

# %% [markdown]
# ## Step 1. 사전 설정

# %%
import pandas as pd
import numpy as np
from scipy import stats
import gc
import os
import math
import warnings
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# 파일 위치 사전 정의
warnings.filterwarnings("ignore")
DATA_RAW_DIR = './data/raw'
DATA_OUTPUT_DIR = './data/processed'
ANALYSIS_OUTPUT_DIR = './outputs/tables'
SAMPLING_OUTPUT_DIR = './data/external'

# 한글 폰트 설정
fe = fm.FontEntry(
fname=r'/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf',
name='NanumGothic')
fm.fontManager.ttflist.insert(0, fe)
plt.rcParams.update({'font.size': 18, 'font.family': 'NanumGothic'})

# 마이너스 표시 문제
mpl.rcParams['axes.unicode_minus'] = False

print("모듈 import 완료")
# Out:
# 모듈 import 완료

# %% [markdown]
# ## Step 2. 월별 데이터로 병합

# %%
## 1. 경기도 카드 소비 데이터 로드

# 작업 해야 하는 파일 불러오기
all_files = os.listdir(DATA_RAW_DIR)
csv_files = sorted([f for f in all_files if f.startswith('tbsh_gyeonggi_day_') and f.endswith('.csv')])

# 이미 작업한 파일 찾기
exist_files = sorted([f for f in os.listdir(DATA_OUTPUT_DIR) if f.startswith('gyeonggi_') and f.endswith('.csv')])
# 이미 작업한 개월 
aleady_processed_months = {f.replace('gyeonggi_', '').replace('.csv', '') for f in exist_files}
# 작업 해야하는 개월
all_months = [x for x in [f"{year}{month:02d}" for year in range(2022, 2026) for month in range(1, 13)] if x <= "202509"]
target_months = sorted([x for x in all_months if x not in aleady_processed_months])

print("경기도 카드 소비 데이터 로드")
print(f"\nLoading {len(csv_files)} CSV files")

## 2. 월별로 파일 그룹화

# 파일명에서 연월 추출하는 함수
def extract_month(filename):
    parts = filename.split('_')
    if len(parts) >= 4:
        return parts[3]
    return None

monthly_files = {}

for filename in csv_files:
    months = extract_month(filename)
    if months:
        monthly_files.setdefault(months, []).append(filename)

print(f"그룹화 완료: {len(monthly_files)}개월")

# 디버깅용 변수
success_count = 0
failed_months = []
# Out:
# 경기도 카드 소비 데이터 로드
#
# Loading 459 CSV files
# 그룹화 완료: 45개월

# %%
## 3. 월별 카드 소비 데이터 병합

for month in sorted(target_months):
    month_files = monthly_files[month]
    print(f"\n[{month}] 처리 중... ({len(month_files)}개 파일)")    
    dfs = []
    
    # 월별 데이터 병합 시도 (인코딩 관련 에러 해결 코드 추가)
    for filename in month_files:
        filepath = os.path.join(DATA_RAW_DIR, filename)
        df_temp = None
        for encoding in ['utf-8', 'euc-kr', 'cp949']:
            try:
                df_temp = pd.read_csv(filepath, encoding=encoding)
                print(f"  O {filename:50s} | {len(df_temp):7,d} rows")
                break
            except:
                continue
        if df_temp is not None:
            dfs.append(df_temp)
    
    if len(dfs) > 0:
        df_month = pd.concat(dfs, ignore_index=True)
        
        # 저장 경로
        output_file = os.path.join(DATA_OUTPUT_DIR, f"gyeonggi_{month}.csv")
        
        # csv로 저장
        df_month.to_csv(output_file, index=False)
        
        file_size_mb = os.path.getsize(output_file) / 1024**2
        print(f"  저장 완료: {output_file}")
        print(f"    - 행: {len(df_month):,}")
        print(f"    - 크기: {file_size_mb:.2f} MB")
        
        success_count += 1
        
        # 메모리 정리
        del df_month, dfs
        gc.collect()
    
    else:
        print(f"  X {month}월 데이터 로드 실패")
        failed_months.append(month)

## 4. 완료
print(f"완료: {success_count}개월 저장 완료")

if failed_months:
    print(f"X 실패: {len(failed_months)}개월 ({', '.join(failed_months)})")
# Out:
# [202201] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202201_광명시.csv                   | 632,806 rows
#   O tbsh_gyeonggi_day_202201_부천시.csv                   | 1,475,049 rows
#   O tbsh_gyeonggi_day_202201_수원시.csv                   | 2,116,088 rows
#   O tbsh_gyeonggi_day_202201_시흥시.csv                   | 866,931 rows
#   O tbsh_gyeonggi_day_202201_안산시.csv                   | 1,149,994 rows
#   O tbsh_gyeonggi_day_202201_안양시.csv                   | 1,209,953 rows
#   O tbsh_gyeonggi_day_202201_용인시.csv                   | 1,831,905 rows
#   O tbsh_gyeonggi_day_202201_포천시.csv                   | 350,242 rows
#   O tbsh_gyeonggi_day_202201_하남시.csv                   | 577,059 rows
#   O tbsh_gyeonggi_day_202201_화성시.csv                   | 1,269,815 rows
#   저장 완료: ./data/processed/gyeonggi_202201.csv
#     - 행: 11,479,842
#     - 크기: 782.95 MB
#
# [202202] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202202_광명시.csv                   | 560,953 rows
#   O tbsh_gyeonggi_day_202202_부천시.csv                   | 1,299,014 rows
#   O tbsh_gyeonggi_day_202202_수원시.csv                   | 1,876,620 rows
#   O tbsh_gyeonggi_day_202202_시흥시.csv                   | 768,480 rows
#   O tbsh_gyeonggi_day_202202_안산시.csv                   | 1,014,475 rows
#   O tbsh_gyeonggi_day_202202_안양시.csv                   | 1,069,808 rows
#   O tbsh_gyeonggi_day_202202_용인시.csv                   | 1,641,322 rows
#   O tbsh_gyeonggi_day_202202_포천시.csv                   | 306,946 rows
#   O tbsh_gyeonggi_day_202202_하남시.csv                   | 515,922 rows
#   O tbsh_gyeonggi_day_202202_화성시.csv                   | 1,137,798 rows
#   저장 완료: ./data/processed/gyeonggi_202202.csv
#     - 행: 10,191,338
#     - 크기: 695.12 MB
#
# [202203] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202203_광명시.csv                   | 663,542 rows
#   O tbsh_gyeonggi_day_202203_부천시.csv                   | 1,543,646 rows
#   O tbsh_gyeonggi_day_202203_수원시.csv                   | 2,221,807 rows
#   O tbsh_gyeonggi_day_202203_시흥시.csv                   | 913,072 rows
#   O tbsh_gyeonggi_day_202203_안산시.csv                   | 1,207,878 rows
#   O tbsh_gyeonggi_day_202203_안양시.csv                   | 1,271,033 rows
#   O tbsh_gyeonggi_day_202203_용인시.csv                   | 1,954,357 rows
#   O tbsh_gyeonggi_day_202203_포천시.csv                   | 372,649 rows
#   O tbsh_gyeonggi_day_202203_하남시.csv                   | 611,547 rows
#   O tbsh_gyeonggi_day_202203_화성시.csv                   | 1,347,455 rows
#   저장 완료: ./data/processed/gyeonggi_202203.csv
#     - 행: 12,106,986
#     - 크기: 825.72 MB
#
# [202204] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202204_광명시.csv                   | 684,964 rows
#   O tbsh_gyeonggi_day_202204_부천시.csv                   | 1,591,642 rows
#   O tbsh_gyeonggi_day_202204_수원시.csv                   | 2,292,503 rows
#   O tbsh_gyeonggi_day_202204_시흥시.csv                   | 938,629 rows
#   O tbsh_gyeonggi_day_202204_안산시.csv                   | 1,244,741 rows
#   O tbsh_gyeonggi_day_202204_안양시.csv                   | 1,304,685 rows
#   O tbsh_gyeonggi_day_202204_용인시.csv                   | 2,016,887 rows
#   O tbsh_gyeonggi_day_202204_포천시.csv                   | 401,345 rows
#   O tbsh_gyeonggi_day_202204_하남시.csv                   | 632,214 rows
#   O tbsh_gyeonggi_day_202204_화성시.csv                   | 1,392,975 rows
#   저장 완료: ./data/processed/gyeonggi_202204.csv
#     - 행: 12,500,585
#     - 크기: 852.52 MB
#
# [202205] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202205_광명시.csv                   | 721,010 rows
#   O tbsh_gyeonggi_day_202205_부천시.csv                   | 1,681,890 rows
#   O tbsh_gyeonggi_day_202205_수원시.csv                   | 2,424,239 rows
#   O tbsh_gyeonggi_day_202205_시흥시.csv                   | 993,088 rows
#   O tbsh_gyeonggi_day_202205_안산시.csv                   | 1,317,602 rows
#   O tbsh_gyeonggi_day_202205_안양시.csv                   | 1,378,619 rows
#   O tbsh_gyeonggi_day_202205_용인시.csv                   | 2,132,831 rows
#   O tbsh_gyeonggi_day_202205_포천시.csv                   | 427,548 rows
#   O tbsh_gyeonggi_day_202205_하남시.csv                   | 669,164 rows
#   O tbsh_gyeonggi_day_202205_화성시.csv                   | 1,472,392 rows
#   저장 완료: ./data/processed/gyeonggi_202205.csv
#     - 행: 13,218,383
#     - 크기: 901.16 MB
#
# [202206] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202206_광명시.csv                   | 693,311 rows
#   O tbsh_gyeonggi_day_202206_부천시.csv                   | 1,622,517 rows
#   O tbsh_gyeonggi_day_202206_수원시.csv                   | 2,342,857 rows
#   O tbsh_gyeonggi_day_202206_시흥시.csv                   | 960,184 rows
#   O tbsh_gyeonggi_day_202206_안산시.csv                   | 1,276,190 rows
#   O tbsh_gyeonggi_day_202206_안양시.csv                   | 1,330,454 rows
#   O tbsh_gyeonggi_day_202206_용인시.csv                   | 2,050,453 rows
#   O tbsh_gyeonggi_day_202206_포천시.csv                   | 401,776 rows
#   O tbsh_gyeonggi_day_202206_하남시.csv                   | 646,442 rows
#   O tbsh_gyeonggi_day_202206_화성시.csv                   | 1,422,755 rows
#   저장 완료: ./data/processed/gyeonggi_202206.csv
#     - 행: 12,746,939
#     - 크기: 868.62 MB
#
# [202207] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202207_광명시.csv                   | 707,940 rows
#   O tbsh_gyeonggi_day_202207_부천시.csv                   | 1,641,866 rows
#   O tbsh_gyeonggi_day_202207_수원시.csv                   | 2,381,267 rows
#   O tbsh_gyeonggi_day_202207_시흥시.csv                   | 975,669 rows
#   O tbsh_gyeonggi_day_202207_안산시.csv                   | 1,305,496 rows
#   O tbsh_gyeonggi_day_202207_안양시.csv                   | 1,353,981 rows
#   O tbsh_gyeonggi_day_202207_용인시.csv                   | 2,081,603 rows
#   O tbsh_gyeonggi_day_202207_포천시.csv                   | 412,242 rows
#   O tbsh_gyeonggi_day_202207_하남시.csv                   | 662,404 rows
#   O tbsh_gyeonggi_day_202207_화성시.csv                   | 1,453,430 rows
#   저장 완료: ./data/processed/gyeonggi_202207.csv
#     - 행: 12,975,898
#     - 크기: 883.92 MB
#
# [202208] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202208_광명시.csv                   | 709,306 rows
#   O tbsh_gyeonggi_day_202208_부천시.csv                   | 1,657,796 rows
#   O tbsh_gyeonggi_day_202208_수원시.csv                   | 2,404,221 rows
#   O tbsh_gyeonggi_day_202208_시흥시.csv                   | 979,115 rows
#   O tbsh_gyeonggi_day_202208_안산시.csv                   | 1,307,582 rows
#   O tbsh_gyeonggi_day_202208_안양시.csv                   | 1,356,181 rows
#   O tbsh_gyeonggi_day_202208_용인시.csv                   | 2,088,974 rows
#   O tbsh_gyeonggi_day_202208_포천시.csv                   | 418,332 rows
#   O tbsh_gyeonggi_day_202208_하남시.csv                   | 667,777 rows
#   O tbsh_gyeonggi_day_202208_화성시.csv                   | 1,458,618 rows
#   저장 완료: ./data/processed/gyeonggi_202208.csv
#     - 행: 13,047,902
#     - 크기: 888.85 MB
#
# [202209] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202209_광명시.csv                   | 678,058 rows
#   O tbsh_gyeonggi_day_202209_부천시.csv                   | 1,603,215 rows
#   O tbsh_gyeonggi_day_202209_수원시.csv                   | 2,308,999 rows
#   O tbsh_gyeonggi_day_202209_시흥시.csv                   | 945,121 rows
#   O tbsh_gyeonggi_day_202209_안산시.csv                   | 1,263,251 rows
#   O tbsh_gyeonggi_day_202209_안양시.csv                   | 1,307,023 rows
#   O tbsh_gyeonggi_day_202209_용인시.csv                   | 2,021,544 rows
#   O tbsh_gyeonggi_day_202209_포천시.csv                   | 401,079 rows
#   O tbsh_gyeonggi_day_202209_하남시.csv                   | 631,188 rows
#   O tbsh_gyeonggi_day_202209_화성시.csv                   | 1,400,472 rows
#   저장 완료: ./data/processed/gyeonggi_202209.csv
#     - 행: 12,559,950
#     - 크기: 856.27 MB
#
# [202210] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202210_광명시.csv                   | 709,820 rows
#   O tbsh_gyeonggi_day_202210_부천시.csv                   | 1,687,849 rows
#   O tbsh_gyeonggi_day_202210_수원시.csv                   | 2,428,078 rows
#   O tbsh_gyeonggi_day_202210_시흥시.csv                   | 993,115 rows
#   O tbsh_gyeonggi_day_202210_안산시.csv                   | 1,325,822 rows
#   O tbsh_gyeonggi_day_202210_안양시.csv                   | 1,373,215 rows
#   O tbsh_gyeonggi_day_202210_용인시.csv                   | 2,116,773 rows
#   O tbsh_gyeonggi_day_202210_포천시.csv                   | 423,294 rows
#   O tbsh_gyeonggi_day_202210_하남시.csv                   | 661,089 rows
#   O tbsh_gyeonggi_day_202210_화성시.csv                   | 1,466,707 rows
#   저장 완료: ./data/processed/gyeonggi_202210.csv
#     - 행: 13,185,762
#     - 크기: 898.62 MB
#
# [202211] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202211_광명시.csv                   | 680,512 rows
#   O tbsh_gyeonggi_day_202211_부천시.csv                   | 1,627,997 rows
#   O tbsh_gyeonggi_day_202211_수원시.csv                   | 2,340,175 rows
#   O tbsh_gyeonggi_day_202211_시흥시.csv                   | 952,428 rows
#   O tbsh_gyeonggi_day_202211_안산시.csv                   | 1,267,777 rows
#   O tbsh_gyeonggi_day_202211_안양시.csv                   | 1,330,011 rows
#   O tbsh_gyeonggi_day_202211_용인시.csv                   | 2,026,287 rows
#   O tbsh_gyeonggi_day_202211_포천시.csv                   | 388,500 rows
#   O tbsh_gyeonggi_day_202211_하남시.csv                   | 634,747 rows
#   O tbsh_gyeonggi_day_202211_화성시.csv                   | 1,411,865 rows
#   저장 완료: ./data/processed/gyeonggi_202211.csv
#     - 행: 12,660,299
#     - 크기: 863.06 MB
#
# [202212] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202212_광명시.csv                   | 700,079 rows
#   O tbsh_gyeonggi_day_202212_부천시.csv                   | 1,670,568 rows
#   O tbsh_gyeonggi_day_202212_수원시.csv                   | 2,394,900 rows
#   O tbsh_gyeonggi_day_202212_시흥시.csv                   | 971,811 rows
#   O tbsh_gyeonggi_day_202212_안산시.csv                   | 1,304,959 rows
#   O tbsh_gyeonggi_day_202212_안양시.csv                   | 1,359,736 rows
#   O tbsh_gyeonggi_day_202212_용인시.csv                   | 2,039,992 rows
#   O tbsh_gyeonggi_day_202212_포천시.csv                   | 372,247 rows
#   O tbsh_gyeonggi_day_202212_하남시.csv                   | 659,128 rows
#   O tbsh_gyeonggi_day_202212_화성시.csv                   | 1,429,522 rows
#   저장 완료: ./data/processed/gyeonggi_202212.csv
#     - 행: 12,902,942
#     - 크기: 880.00 MB
#
# [202301] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202301_광명시.csv                   | 668,310 rows
#   O tbsh_gyeonggi_day_202301_부천시.csv                   | 1,599,177 rows
#   O tbsh_gyeonggi_day_202301_수원시.csv                   | 2,288,329 rows
#   O tbsh_gyeonggi_day_202301_시흥시.csv                   | 928,106 rows
#   O tbsh_gyeonggi_day_202301_안산시.csv                   | 1,237,555 rows
#   O tbsh_gyeonggi_day_202301_안양시.csv                   | 1,285,200 rows
#   O tbsh_gyeonggi_day_202301_용인시.csv                   | 1,938,060 rows
#   O tbsh_gyeonggi_day_202301_포천시.csv                   | 354,410 rows
#   O tbsh_gyeonggi_day_202301_하남시.csv                   | 629,810 rows
#   O tbsh_gyeonggi_day_202301_화성시.csv                   | 1,371,679 rows
#   저장 완료: ./data/processed/gyeonggi_202301.csv
#     - 행: 12,300,636
#     - 크기: 838.52 MB
#
# [202302] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202302_광명시.csv                   | 634,180 rows
#   O tbsh_gyeonggi_day_202302_부천시.csv                   | 1,527,981 rows
#   O tbsh_gyeonggi_day_202302_수원시.csv                   | 2,188,922 rows
#   O tbsh_gyeonggi_day_202302_시흥시.csv                   | 886,282 rows
#   O tbsh_gyeonggi_day_202302_안산시.csv                   | 1,177,318 rows
#   O tbsh_gyeonggi_day_202302_안양시.csv                   | 1,232,939 rows
#   O tbsh_gyeonggi_day_202302_용인시.csv                   | 1,868,206 rows
#   O tbsh_gyeonggi_day_202302_포천시.csv                   | 340,576 rows
#   O tbsh_gyeonggi_day_202302_하남시.csv                   | 603,411 rows
#   O tbsh_gyeonggi_day_202302_화성시.csv                   | 1,311,473 rows
#   저장 완료: ./data/processed/gyeonggi_202302.csv
#     - 행: 11,771,288
#     - 크기: 802.42 MB
#
# [202303] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202303_광명시.csv                   | 712,265 rows
#   O tbsh_gyeonggi_day_202303_부천시.csv                   | 1,737,696 rows
#   O tbsh_gyeonggi_day_202303_수원시.csv                   | 2,485,298 rows
#   O tbsh_gyeonggi_day_202303_시흥시.csv                   | 1,010,247 rows
#   O tbsh_gyeonggi_day_202303_안산시.csv                   | 1,336,377 rows
#   O tbsh_gyeonggi_day_202303_안양시.csv                   | 1,393,710 rows
#   O tbsh_gyeonggi_day_202303_용인시.csv                   | 2,149,892 rows
#   O tbsh_gyeonggi_day_202303_포천시.csv                   | 404,469 rows
#   O tbsh_gyeonggi_day_202303_하남시.csv                   | 685,960 rows
#   O tbsh_gyeonggi_day_202303_화성시.csv                   | 1,488,182 rows
#   저장 완료: ./data/processed/gyeonggi_202303.csv
#     - 행: 13,404,096
#     - 크기: 914.65 MB
#
# [202304] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202304_광명시.csv                   | 685,694 rows
#   O tbsh_gyeonggi_day_202304_부천시.csv                   | 1,695,502 rows
#   O tbsh_gyeonggi_day_202304_수원시.csv                   | 2,429,363 rows
#   O tbsh_gyeonggi_day_202304_시흥시.csv                   | 989,844 rows
#   O tbsh_gyeonggi_day_202304_안산시.csv                   | 1,308,354 rows
#   O tbsh_gyeonggi_day_202304_안양시.csv                   | 1,351,704 rows
#   O tbsh_gyeonggi_day_202304_용인시.csv                   | 2,102,093 rows
#   O tbsh_gyeonggi_day_202304_포천시.csv                   | 407,150 rows
#   O tbsh_gyeonggi_day_202304_하남시.csv                   | 676,805 rows
#   O tbsh_gyeonggi_day_202304_화성시.csv                   | 1,457,292 rows
#   저장 완료: ./data/processed/gyeonggi_202304.csv
#     - 행: 13,103,801
#     - 크기: 893.52 MB
#
# [202305] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202305_광명시.csv                   | 718,662 rows
#   O tbsh_gyeonggi_day_202305_부천시.csv                   | 1,775,502 rows
#   O tbsh_gyeonggi_day_202305_수원시.csv                   | 2,542,231 rows
#   O tbsh_gyeonggi_day_202305_시흥시.csv                   | 1,042,563 rows
#   O tbsh_gyeonggi_day_202305_안산시.csv                   | 1,366,368 rows
#   O tbsh_gyeonggi_day_202305_안양시.csv                   | 1,411,843 rows
#   O tbsh_gyeonggi_day_202305_용인시.csv                   | 2,195,770 rows
#   O tbsh_gyeonggi_day_202305_포천시.csv                   | 434,399 rows
#   O tbsh_gyeonggi_day_202305_하남시.csv                   | 708,819 rows
#   O tbsh_gyeonggi_day_202305_화성시.csv                   | 1,524,147 rows
#   저장 완료: ./data/processed/gyeonggi_202305.csv
#     - 행: 13,720,304
#     - 크기: 935.69 MB
#
# [202306] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202306_광명시.csv                   | 705,023 rows
#   O tbsh_gyeonggi_day_202306_부천시.csv                   | 1,735,621 rows
#   O tbsh_gyeonggi_day_202306_수원시.csv                   | 2,491,456 rows
#   O tbsh_gyeonggi_day_202306_시흥시.csv                   | 1,023,661 rows
#   O tbsh_gyeonggi_day_202306_안산시.csv                   | 1,332,057 rows
#   O tbsh_gyeonggi_day_202306_안양시.csv                   | 1,384,589 rows
#   O tbsh_gyeonggi_day_202306_용인시.csv                   | 2,139,599 rows
#   O tbsh_gyeonggi_day_202306_포천시.csv                   | 421,101 rows
#   O tbsh_gyeonggi_day_202306_하남시.csv                   | 690,894 rows
#   O tbsh_gyeonggi_day_202306_화성시.csv                   | 1,493,966 rows
#   저장 완료: ./data/processed/gyeonggi_202306.csv
#     - 행: 13,417,967
#     - 크기: 914.71 MB
#
# [202307] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202307_광명시.csv                   | 719,984 rows
#   O tbsh_gyeonggi_day_202307_부천시.csv                   | 1,760,927 rows
#   O tbsh_gyeonggi_day_202307_수원시.csv                   | 2,512,966 rows
#   O tbsh_gyeonggi_day_202307_시흥시.csv                   | 1,036,585 rows
#   O tbsh_gyeonggi_day_202307_안산시.csv                   | 1,345,099 rows
#   O tbsh_gyeonggi_day_202307_안양시.csv                   | 1,404,933 rows
#   O tbsh_gyeonggi_day_202307_용인시.csv                   | 2,145,535 rows
#   O tbsh_gyeonggi_day_202307_포천시.csv                   | 421,391 rows
#   O tbsh_gyeonggi_day_202307_하남시.csv                   | 708,224 rows
#   O tbsh_gyeonggi_day_202307_화성시.csv                   | 1,510,070 rows
#   저장 완료: ./data/processed/gyeonggi_202307.csv
#     - 행: 13,565,714
#     - 크기: 924.08 MB
#
# [202308] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202308_광명시.csv                   | 723,534 rows
#   O tbsh_gyeonggi_day_202308_부천시.csv                   | 1,764,493 rows
#   O tbsh_gyeonggi_day_202308_수원시.csv                   | 2,527,433 rows
#   O tbsh_gyeonggi_day_202308_시흥시.csv                   | 1,040,448 rows
#   O tbsh_gyeonggi_day_202308_안산시.csv                   | 1,346,745 rows
#   O tbsh_gyeonggi_day_202308_안양시.csv                   | 1,411,484 rows
#   O tbsh_gyeonggi_day_202308_용인시.csv                   | 2,170,157 rows
#   O tbsh_gyeonggi_day_202308_포천시.csv                   | 430,319 rows
#   O tbsh_gyeonggi_day_202308_하남시.csv                   | 714,047 rows
#   O tbsh_gyeonggi_day_202308_화성시.csv                   | 1,521,240 rows
#   저장 완료: ./data/processed/gyeonggi_202308.csv
#     - 행: 13,649,900
#     - 크기: 929.74 MB
#
# [202309] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202309_광명시.csv                   | 686,168 rows
#   O tbsh_gyeonggi_day_202309_부천시.csv                   | 1,704,936 rows
#   O tbsh_gyeonggi_day_202309_수원시.csv                   | 2,422,882 rows
#   O tbsh_gyeonggi_day_202309_시흥시.csv                   | 1,000,867 rows
#   O tbsh_gyeonggi_day_202309_안산시.csv                   | 1,298,823 rows
#   O tbsh_gyeonggi_day_202309_안양시.csv                   | 1,354,528 rows
#   O tbsh_gyeonggi_day_202309_용인시.csv                   | 2,082,711 rows
#   O tbsh_gyeonggi_day_202309_포천시.csv                   | 416,872 rows
#   O tbsh_gyeonggi_day_202309_하남시.csv                   | 678,046 rows
#   O tbsh_gyeonggi_day_202309_화성시.csv                   | 1,460,945 rows
#   저장 완료: ./data/processed/gyeonggi_202309.csv
#     - 행: 13,106,778
#     - 크기: 893.28 MB
#
# [202310] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202310_광명시.csv                   | 710,187 rows
#   O tbsh_gyeonggi_day_202310_부천시.csv                   | 1,764,639 rows
#   O tbsh_gyeonggi_day_202310_수원시.csv                   | 2,520,493 rows
#   O tbsh_gyeonggi_day_202310_시흥시.csv                   | 1,037,711 rows
#   O tbsh_gyeonggi_day_202310_안산시.csv                   | 1,347,934 rows
#   O tbsh_gyeonggi_day_202310_안양시.csv                   | 1,401,669 rows
#   O tbsh_gyeonggi_day_202310_용인시.csv                   | 2,160,938 rows
#   O tbsh_gyeonggi_day_202310_포천시.csv                   | 430,882 rows
#   O tbsh_gyeonggi_day_202310_하남시.csv                   | 699,866 rows
#   O tbsh_gyeonggi_day_202310_화성시.csv                   | 1,513,810 rows
#   저장 완료: ./data/processed/gyeonggi_202310.csv
#     - 행: 13,588,129
#     - 크기: 926.10 MB
#
# [202311] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202311_광명시.csv                   | 677,749 rows
#   O tbsh_gyeonggi_day_202311_부천시.csv                   | 1,696,895 rows
#   O tbsh_gyeonggi_day_202311_수원시.csv                   | 2,410,268 rows
#   O tbsh_gyeonggi_day_202311_시흥시.csv                   | 988,514 rows
#   O tbsh_gyeonggi_day_202311_안산시.csv                   | 1,283,149 rows
#   O tbsh_gyeonggi_day_202311_안양시.csv                   | 1,353,319 rows
#   O tbsh_gyeonggi_day_202311_용인시.csv                   | 2,063,138 rows
#   O tbsh_gyeonggi_day_202311_포천시.csv                   | 394,997 rows
#   O tbsh_gyeonggi_day_202311_하남시.csv                   | 665,227 rows
#   O tbsh_gyeonggi_day_202311_화성시.csv                   | 1,448,031 rows
#   저장 완료: ./data/processed/gyeonggi_202311.csv
#     - 행: 12,981,287
#     - 크기: 885.17 MB
#
# [202312] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202312_광명시.csv                   | 708,489 rows
#   O tbsh_gyeonggi_day_202312_부천시.csv                   | 1,739,789 rows
#   O tbsh_gyeonggi_day_202312_수원시.csv                   | 2,475,328 rows
#   O tbsh_gyeonggi_day_202312_시흥시.csv                   | 1,012,299 rows
#   O tbsh_gyeonggi_day_202312_안산시.csv                   | 1,308,641 rows
#   O tbsh_gyeonggi_day_202312_안양시.csv                   | 1,386,606 rows
#   O tbsh_gyeonggi_day_202312_용인시.csv                   | 2,080,569 rows
#   O tbsh_gyeonggi_day_202312_포천시.csv                   | 383,080 rows
#   O tbsh_gyeonggi_day_202312_하남시.csv                   | 681,538 rows
#   O tbsh_gyeonggi_day_202312_화성시.csv                   | 1,484,950 rows
#   저장 완료: ./data/processed/gyeonggi_202312.csv
#     - 행: 13,261,289
#     - 크기: 904.18 MB
#
# [202401] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202401_광명시.csv                   | 691,175 rows
#   O tbsh_gyeonggi_day_202401_부천시.csv                   | 1,704,547 rows
#   O tbsh_gyeonggi_day_202401_수원시.csv                   | 2,419,681 rows
#   O tbsh_gyeonggi_day_202401_시흥시.csv                   | 992,904 rows
#   O tbsh_gyeonggi_day_202401_안산시.csv                   | 1,274,735 rows
#   O tbsh_gyeonggi_day_202401_안양시.csv                   | 1,365,107 rows
#   O tbsh_gyeonggi_day_202401_용인시.csv                   | 2,036,641 rows
#   O tbsh_gyeonggi_day_202401_포천시.csv                   | 367,105 rows
#   O tbsh_gyeonggi_day_202401_하남시.csv                   | 668,310 rows
#   O tbsh_gyeonggi_day_202401_화성시.csv                   | 1,455,611 rows
#   저장 완료: ./data/processed/gyeonggi_202401.csv
#     - 행: 12,975,816
#     - 크기: 884.30 MB
#
# [202402] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202402_광명시.csv                   | 637,858 rows
#   O tbsh_gyeonggi_day_202402_부천시.csv                   | 1,655,148 rows
#   O tbsh_gyeonggi_day_202402_수원시.csv                   | 2,247,683 rows
#   O tbsh_gyeonggi_day_202402_시흥시.csv                   | 924,955 rows
#   O tbsh_gyeonggi_day_202402_안산시.csv                   | 1,179,704 rows
#   O tbsh_gyeonggi_day_202402_안양시.csv                   | 1,261,031 rows
#   O tbsh_gyeonggi_day_202402_용인시.csv                   | 1,896,331 rows
#   O tbsh_gyeonggi_day_202402_포천시.csv                   | 350,951 rows
#   O tbsh_gyeonggi_day_202402_하남시.csv                   | 624,223 rows
#   O tbsh_gyeonggi_day_202402_화성시.csv                   | 1,354,823 rows
#   저장 완료: ./data/processed/gyeonggi_202402.csv
#     - 행: 12,132,707
#     - 크기: 827.26 MB
#
# [202403] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202403_광명시.csv                   | 708,717 rows
#   O tbsh_gyeonggi_day_202403_부천시.csv                   | 1,841,230 rows
#   O tbsh_gyeonggi_day_202403_수원시.csv                   | 2,501,913 rows
#   O tbsh_gyeonggi_day_202403_시흥시.csv                   | 1,036,909 rows
#   O tbsh_gyeonggi_day_202403_안산시.csv                   | 1,321,245 rows
#   O tbsh_gyeonggi_day_202403_안양시.csv                   | 1,414,758 rows
#   O tbsh_gyeonggi_day_202403_용인시.csv                   | 2,158,679 rows
#   O tbsh_gyeonggi_day_202403_포천시.csv                   | 404,769 rows
#   O tbsh_gyeonggi_day_202403_하남시.csv                   | 695,982 rows
#   O tbsh_gyeonggi_day_202403_화성시.csv                   | 1,522,765 rows
#   저장 완료: ./data/processed/gyeonggi_202403.csv
#     - 행: 13,606,967
#     - 크기: 928.10 MB
#
# [202404] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202404_광명시.csv                   | 698,738 rows
#   O tbsh_gyeonggi_day_202404_부천시.csv                   | 1,812,849 rows
#   O tbsh_gyeonggi_day_202404_수원시.csv                   | 2,472,092 rows
#   O tbsh_gyeonggi_day_202404_시흥시.csv                   | 1,022,671 rows
#   O tbsh_gyeonggi_day_202404_안산시.csv                   | 1,303,938 rows
#   O tbsh_gyeonggi_day_202404_안양시.csv                   | 1,394,626 rows
#   O tbsh_gyeonggi_day_202404_용인시.csv                   | 2,141,207 rows
#   O tbsh_gyeonggi_day_202404_포천시.csv                   | 413,459 rows
#   O tbsh_gyeonggi_day_202404_하남시.csv                   | 687,694 rows
#   O tbsh_gyeonggi_day_202404_화성시.csv                   | 1,504,485 rows
#   저장 완료: ./data/processed/gyeonggi_202404.csv
#     - 행: 13,451,759
#     - 크기: 917.61 MB
#
# [202405] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202405_광명시.csv                   | 718,429 rows
#   O tbsh_gyeonggi_day_202405_부천시.csv                   | 1,793,898 rows
#   O tbsh_gyeonggi_day_202405_수원시.csv                   | 2,565,314 rows
#   O tbsh_gyeonggi_day_202405_시흥시.csv                   | 1,062,736 rows
#   O tbsh_gyeonggi_day_202405_안산시.csv                   | 1,352,907 rows
#   O tbsh_gyeonggi_day_202405_안양시.csv                   | 1,436,028 rows
#   O tbsh_gyeonggi_day_202405_용인시.csv                   | 2,217,305 rows
#   O tbsh_gyeonggi_day_202405_포천시.csv                   | 430,783 rows
#   O tbsh_gyeonggi_day_202405_하남시.csv                   | 716,843 rows
#   O tbsh_gyeonggi_day_202405_화성시.csv                   | 1,561,602 rows
#   저장 완료: ./data/processed/gyeonggi_202405.csv
#     - 행: 13,855,845
#     - 크기: 944.92 MB
#
# [202406] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202406_광명시.csv                   | 698,651 rows
#   O tbsh_gyeonggi_day_202406_부천시.csv                   | 1,729,713 rows
#   O tbsh_gyeonggi_day_202406_수원시.csv                   | 2,480,026 rows
#   O tbsh_gyeonggi_day_202406_시흥시.csv                   | 1,032,720 rows
#   O tbsh_gyeonggi_day_202406_안산시.csv                   | 1,311,223 rows
#   O tbsh_gyeonggi_day_202406_안양시.csv                   | 1,392,823 rows
#   O tbsh_gyeonggi_day_202406_용인시.csv                   | 2,139,750 rows
#   O tbsh_gyeonggi_day_202406_포천시.csv                   | 418,065 rows
#   O tbsh_gyeonggi_day_202406_하남시.csv                   | 690,711 rows
#   O tbsh_gyeonggi_day_202406_화성시.csv                   | 1,513,278 rows
#   저장 완료: ./data/processed/gyeonggi_202406.csv
#     - 행: 13,406,960
#     - 크기: 914.04 MB
#
# [202407] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202407_광명시.csv                   | 712,966 rows
#   O tbsh_gyeonggi_day_202407_부천시.csv                   | 1,848,142 rows
#   O tbsh_gyeonggi_day_202407_수원시.csv                   | 2,523,400 rows
#   O tbsh_gyeonggi_day_202407_시흥시.csv                   | 1,051,485 rows
#   O tbsh_gyeonggi_day_202407_안산시.csv                   | 1,328,334 rows
#   O tbsh_gyeonggi_day_202407_안양시.csv                   | 1,423,447 rows
#   O tbsh_gyeonggi_day_202407_용인시.csv                   | 2,155,642 rows
#   O tbsh_gyeonggi_day_202407_포천시.csv                   | 407,646 rows
#   O tbsh_gyeonggi_day_202407_하남시.csv                   | 707,323 rows
#   O tbsh_gyeonggi_day_202407_화성시.csv                   | 1,542,509 rows
#   저장 완료: ./data/processed/gyeonggi_202407.csv
#     - 행: 13,700,894
#     - 크기: 933.86 MB
#
# [202408] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202408_광명시.csv                   | 717,534 rows
#   O tbsh_gyeonggi_day_202408_부천시.csv                   | 1,850,650 rows
#   O tbsh_gyeonggi_day_202408_수원시.csv                   | 2,531,147 rows
#   O tbsh_gyeonggi_day_202408_시흥시.csv                   | 1,059,097 rows
#   O tbsh_gyeonggi_day_202408_안산시.csv                   | 1,335,071 rows
#   O tbsh_gyeonggi_day_202408_안양시.csv                   | 1,428,467 rows
#   O tbsh_gyeonggi_day_202408_용인시.csv                   | 2,174,627 rows
#   O tbsh_gyeonggi_day_202408_포천시.csv                   | 434,651 rows
#   O tbsh_gyeonggi_day_202408_하남시.csv                   | 713,619 rows
#   O tbsh_gyeonggi_day_202408_화성시.csv                   | 1,555,496 rows
#   저장 완료: ./data/processed/gyeonggi_202408.csv
#     - 행: 13,800,359
#     - 크기: 940.75 MB
#
# [202409] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202409_광명시.csv                   | 671,260 rows
#   O tbsh_gyeonggi_day_202409_부천시.csv                   | 1,742,920 rows
#   O tbsh_gyeonggi_day_202409_수원시.csv                   | 2,387,766 rows
#   O tbsh_gyeonggi_day_202409_시흥시.csv                   | 1,000,084 rows
#   O tbsh_gyeonggi_day_202409_안산시.csv                   | 1,263,459 rows
#   O tbsh_gyeonggi_day_202409_안양시.csv                   | 1,346,593 rows
#   O tbsh_gyeonggi_day_202409_용인시.csv                   | 2,064,953 rows
#   O tbsh_gyeonggi_day_202409_포천시.csv                   | 408,453 rows
#   O tbsh_gyeonggi_day_202409_하남시.csv                   | 668,495 rows
#   O tbsh_gyeonggi_day_202409_화성시.csv                   | 1,470,168 rows
#   저장 완료: ./data/processed/gyeonggi_202409.csv
#     - 행: 13,024,151
#     - 크기: 888.19 MB
#
# [202410] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202410_광명시.csv                   | 708,893 rows
#   O tbsh_gyeonggi_day_202410_부천시.csv                   | 1,845,016 rows
#   O tbsh_gyeonggi_day_202410_수원시.csv                   | 2,517,060 rows
#   O tbsh_gyeonggi_day_202410_시흥시.csv                   | 1,052,455 rows
#   O tbsh_gyeonggi_day_202410_안산시.csv                   | 1,329,100 rows
#   O tbsh_gyeonggi_day_202410_안양시.csv                   | 1,426,408 rows
#   O tbsh_gyeonggi_day_202410_용인시.csv                   | 2,188,085 rows
#   O tbsh_gyeonggi_day_202410_포천시.csv                   | 427,758 rows
#   O tbsh_gyeonggi_day_202410_하남시.csv                   | 703,060 rows
#   O tbsh_gyeonggi_day_202410_화성시.csv                   | 1,550,761 rows
#   저장 완료: ./data/processed/gyeonggi_202410.csv
#     - 행: 13,748,596
#     - 크기: 937.75 MB
#
# [202411] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202411_광명시.csv                   | 674,443 rows
#   O tbsh_gyeonggi_day_202411_부천시.csv                   | 1,764,195 rows
#   O tbsh_gyeonggi_day_202411_수원시.csv                   | 2,387,561 rows
#   O tbsh_gyeonggi_day_202411_시흥시.csv                   | 993,263 rows
#   O tbsh_gyeonggi_day_202411_안산시.csv                   | 1,261,354 rows
#   O tbsh_gyeonggi_day_202411_안양시.csv                   | 1,362,451 rows
#   O tbsh_gyeonggi_day_202411_용인시.csv                   | 2,062,492 rows
#   O tbsh_gyeonggi_day_202411_포천시.csv                   | 393,189 rows
#   O tbsh_gyeonggi_day_202411_하남시.csv                   | 671,679 rows
#   O tbsh_gyeonggi_day_202411_화성시.csv                   | 1,465,081 rows
#   저장 완료: ./data/processed/gyeonggi_202411.csv
#     - 행: 13,035,708
#     - 크기: 889.60 MB
#
# [202412] 처리 중... (10개 파일)
#   O tbsh_gyeonggi_day_202412_광명시.csv                   | 695,163 rows
#   O tbsh_gyeonggi_day_202412_부천시.csv                   | 1,805,844 rows
#   O tbsh_gyeonggi_day_202412_수원시.csv                   | 2,446,469 rows
#   O tbsh_gyeonggi_day_202412_시흥시.csv                   | 1,017,979 rows
#   O tbsh_gyeonggi_day_202412_안산시.csv                   | 1,286,896 rows
#   O tbsh_gyeonggi_day_202412_안양시.csv                   | 1,387,344 rows
#   O tbsh_gyeonggi_day_202412_용인시.csv                   | 2,089,231 rows
#   O tbsh_gyeonggi_day_202412_포천시.csv                   | 370,299 rows
#   O tbsh_gyeonggi_day_202412_하남시.csv                   | 687,159 rows
#   O tbsh_gyeonggi_day_202412_화성시.csv                   | 1,488,247 rows
#   저장 완료: ./data/processed/gyeonggi_202412.csv
#     - 행: 13,274,631
#     - 크기: 906.15 MB
#
# [202501] 처리 중... (11개 파일)
#   O tbsh_gyeonggi_day_202501_과천시.csv                   | 202,196 rows
#   O tbsh_gyeonggi_day_202501_광명시.csv                   | 667,363 rows
#   O tbsh_gyeonggi_day_202501_수원시.csv                   | 2,317,532 rows
#   O tbsh_gyeonggi_day_202501_시흥시.csv                   | 970,270 rows
#   O tbsh_gyeonggi_day_202501_안산시.csv                   | 1,226,312 rows
#   O tbsh_gyeonggi_day_202501_안양시.csv                   | 1,319,789 rows
#   O tbsh_gyeonggi_day_202501_용인시.csv                   | 1,970,765 rows
#   O tbsh_gyeonggi_day_202501_이천시.csv                   | 478,909 rows
#   O tbsh_gyeonggi_day_202501_포천시.csv                   | 352,875 rows
#   O tbsh_gyeonggi_day_202501_하남시.csv                   | 655,076 rows
#   O tbsh_gyeonggi_day_202501_화성시.csv                   | 1,411,045 rows
#   저장 완료: ./data/processed/gyeonggi_202501.csv
#     - 행: 11,572,132
#     - 크기: 790.18 MB
#
# [202502] 처리 중... (11개 파일)
#   O tbsh_gyeonggi_day_202502_과천시.csv                   | 198,232 rows
#   O tbsh_gyeonggi_day_202502_광명시.csv                   | 608,840 rows
#   O tbsh_gyeonggi_day_202502_수원시.csv                   | 2,155,963 rows
#   O tbsh_gyeonggi_day_202502_시흥시.csv                   | 897,714 rows
#   O tbsh_gyeonggi_day_202502_안산시.csv                   | 1,133,223 rows
#   O tbsh_gyeonggi_day_202502_안양시.csv                   | 1,230,928 rows
#   O tbsh_gyeonggi_day_202502_용인시.csv                   | 1,849,044 rows
#   O tbsh_gyeonggi_day_202502_이천시.csv                   | 441,228 rows
#   O tbsh_gyeonggi_day_202502_포천시.csv                   | 324,023 rows
#   O tbsh_gyeonggi_day_202502_하남시.csv                   | 609,722 rows
#   O tbsh_gyeonggi_day_202502_화성시.csv                   | 1,321,269 rows
#   저장 완료: ./data/processed/gyeonggi_202502.csv
#     - 행: 10,770,186
#     - 크기: 735.52 MB
#
# [202503] 처리 중... (11개 파일)
#   O tbsh_gyeonggi_day_202503_과천시.csv                   | 224,611 rows
#   O tbsh_gyeonggi_day_202503_광명시.csv                   | 695,946 rows
#   O tbsh_gyeonggi_day_202503_수원시.csv                   | 2,461,288 rows
#   O tbsh_gyeonggi_day_202503_시흥시.csv                   | 1,023,564 rows
#   O tbsh_gyeonggi_day_202503_안산시.csv                   | 1,294,121 rows
#   O tbsh_gyeonggi_day_202503_안양시.csv                   | 1,394,522 rows
#   O tbsh_gyeonggi_day_202503_용인시.csv                   | 2,136,735 rows
#   O tbsh_gyeonggi_day_202503_이천시.csv                   | 511,602 rows
#   O tbsh_gyeonggi_day_202503_포천시.csv                   | 388,593 rows
#   O tbsh_gyeonggi_day_202503_하남시.csv                   | 691,072 rows
#   O tbsh_gyeonggi_day_202503_화성시.csv                   | 1,510,313 rows
#   저장 완료: ./data/processed/gyeonggi_202503.csv
#     - 행: 12,332,367
#     - 크기: 842.63 MB
#
# [202504] 처리 중... (11개 파일)
#   O tbsh_gyeonggi_day_202504_과천시.csv                   | 230,643 rows
#   O tbsh_gyeonggi_day_202504_광명시.csv                   | 693,456 rows
#   O tbsh_gyeonggi_day_202504_수원시.csv                   | 2,424,630 rows
#   O tbsh_gyeonggi_day_202504_시흥시.csv                   | 1,000,354 rows
#   O tbsh_gyeonggi_day_202504_안산시.csv                   | 1,271,505 rows
#   O tbsh_gyeonggi_day_202504_안양시.csv                   | 1,372,841 rows
#   O tbsh_gyeonggi_day_202504_용인시.csv                   | 2,117,729 rows
#   O tbsh_gyeonggi_day_202504_이천시.csv                   | 510,676 rows
#   O tbsh_gyeonggi_day_202504_포천시.csv                   | 391,764 rows
#   O tbsh_gyeonggi_day_202504_하남시.csv                   | 681,885 rows
#   O tbsh_gyeonggi_day_202504_화성시.csv                   | 1,494,506 rows
#   저장 완료: ./data/processed/gyeonggi_202504.csv
#     - 행: 12,189,989
#     - 크기: 832.69 MB
#
# [202505] 처리 중... (11개 파일)
#   O tbsh_gyeonggi_day_202505_과천시.csv                   | 237,229 rows
#   O tbsh_gyeonggi_day_202505_광명시.csv                   | 726,366 rows
#   O tbsh_gyeonggi_day_202505_수원시.csv                   | 2,520,937 rows
#   O tbsh_gyeonggi_day_202505_시흥시.csv                   | 1,046,077 rows
#   O tbsh_gyeonggi_day_202505_안산시.csv                   | 1,328,417 rows
#   O tbsh_gyeonggi_day_202505_안양시.csv                   | 1,425,051 rows
#   O tbsh_gyeonggi_day_202505_용인시.csv                   | 2,200,077 rows
#   O tbsh_gyeonggi_day_202505_이천시.csv                   | 535,156 rows
#   O tbsh_gyeonggi_day_202505_포천시.csv                   | 427,075 rows
#   O tbsh_gyeonggi_day_202505_하남시.csv                   | 710,874 rows
#   O tbsh_gyeonggi_day_202505_화성시.csv                   | 1,560,399 rows
#   저장 완료: ./data/processed/gyeonggi_202505.csv
#     - 행: 12,717,658
#     - 크기: 868.61 MB
#
# [202506] 처리 중... (11개 파일)
#   O tbsh_gyeonggi_day_202506_과천시.csv                   | 227,717 rows
#   O tbsh_gyeonggi_day_202506_광명시.csv                   | 702,961 rows
#   O tbsh_gyeonggi_day_202506_수원시.csv                   | 2,428,407 rows
#   O tbsh_gyeonggi_day_202506_시흥시.csv                   | 1,005,614 rows
#   O tbsh_gyeonggi_day_202506_안산시.csv                   | 1,280,138 rows
#   O tbsh_gyeonggi_day_202506_안양시.csv                   | 1,376,688 rows
#   O tbsh_gyeonggi_day_202506_용인시.csv                   | 2,106,922 rows
#   O tbsh_gyeonggi_day_202506_이천시.csv                   | 510,760 rows
#   O tbsh_gyeonggi_day_202506_포천시.csv                   | 404,336 rows
#   O tbsh_gyeonggi_day_202506_하남시.csv                   | 683,630 rows
#   O tbsh_gyeonggi_day_202506_화성시.csv                   | 1,499,702 rows
#   저장 완료: ./data/processed/gyeonggi_202506.csv
#     - 행: 12,226,875
#     - 크기: 834.74 MB
#
# [202507] 처리 중... (11개 파일)
#   O tbsh_gyeonggi_day_202507_과천시.csv                   | 239,366 rows
#   O tbsh_gyeonggi_day_202507_광명시.csv                   | 743,306 rows
#   O tbsh_gyeonggi_day_202507_수원시.csv                   | 2,578,497 rows
#   O tbsh_gyeonggi_day_202507_시흥시.csv                   | 1,072,369 rows
#   O tbsh_gyeonggi_day_202507_안산시.csv                   | 1,354,189 rows
#   O tbsh_gyeonggi_day_202507_안양시.csv                   | 1,457,364 rows
#   O tbsh_gyeonggi_day_202507_용인시.csv                   | 2,217,287 rows
#   O tbsh_gyeonggi_day_202507_이천시.csv                   | 536,716 rows
#   O tbsh_gyeonggi_day_202507_포천시.csv                   | 422,059 rows
#   O tbsh_gyeonggi_day_202507_하남시.csv                   | 726,271 rows
#   O tbsh_gyeonggi_day_202507_화성시.csv                   | 1,595,089 rows
#   저장 완료: ./data/processed/gyeonggi_202507.csv
#     - 행: 12,942,513
#     - 크기: 883.81 MB
#
# [202508] 처리 중... (11개 파일)
#   O tbsh_gyeonggi_day_202508_과천시.csv                   | 240,065 rows
#   O tbsh_gyeonggi_day_202508_광명시.csv                   | 735,224 rows
#   O tbsh_gyeonggi_day_202508_수원시.csv                   | 2,552,044 rows
#   O tbsh_gyeonggi_day_202508_시흥시.csv                   | 1,074,742 rows
#   O tbsh_gyeonggi_day_202508_안산시.csv                   | 1,340,648 rows
#   O tbsh_gyeonggi_day_202508_안양시.csv                   | 1,435,520 rows
#   O tbsh_gyeonggi_day_202508_용인시.csv                   | 2,220,532 rows
#   O tbsh_gyeonggi_day_202508_이천시.csv                   | 534,045 rows
#   O tbsh_gyeonggi_day_202508_포천시.csv                   | 429,620 rows
#   O tbsh_gyeonggi_day_202508_하남시.csv                   | 725,482 rows
#   O tbsh_gyeonggi_day_202508_화성시.csv                   | 1,597,496 rows
#   저장 완료: ./data/processed/gyeonggi_202508.csv
#     - 행: 12,885,418
#     - 크기: 879.55 MB
#
# [202509] 처리 중... (11개 파일)
#   O tbsh_gyeonggi_day_202509_과천시.csv                   | 232,344 rows
#   O tbsh_gyeonggi_day_202509_광명시.csv                   | 712,887 rows
#   O tbsh_gyeonggi_day_202509_수원시.csv                   | 2,485,257 rows
#   O tbsh_gyeonggi_day_202509_시흥시.csv                   | 1,028,348 rows
#   O tbsh_gyeonggi_day_202509_안산시.csv                   | 1,302,605 rows
#   O tbsh_gyeonggi_day_202509_안양시.csv                   | 1,407,514 rows
#   O tbsh_gyeonggi_day_202509_용인시.csv                   | 2,150,944 rows
#   O tbsh_gyeonggi_day_202509_이천시.csv                   | 517,615 rows
#   O tbsh_gyeonggi_day_202509_포천시.csv                   | 409,338 rows
#   O tbsh_gyeonggi_day_202509_하남시.csv                   | 695,688 rows
#   O tbsh_gyeonggi_day_202509_화성시.csv                   | 1,545,411 rows
#   저장 완료: ./data/processed/gyeonggi_202509.csv
#     - 행: 12,487,951
#     - 크기: 852.85 MB
# 완료: 45개월 저장 완료

# %% [markdown]
# ## Step 3. 0값, 음수, 결측치 찾기

# %%
# 매출 데이터 등에서 음수인 값을 찾는 함수
def df_negative(df):
    negatives = {}
    for col in df.select_dtypes(include=[np.number]).columns:
        # 0 이하인 값이 있다면 딕셔너리 값 반환
        count = (df[col]<0).sum()
        if count > 0:
            negatives[col] = {
                'count': count,
                'percentage': (count/len(df))*100,
            }

    return negatives

# 0 값이 있는지 찾는 함수
def df_zero(df, columns=None):
    zeros = {}
    # 컬럼 리스트 columns 인수가 None이라면 모든 수치형 컬럼으로 지정
    if columns is None:
        columns = df.select_dtypes(include=[np.number]).columns
    for col in columns:
        count = (df[col] == 0).sum()
        if count > 0:
            zeros[col] = {
                'count' : count,
                'percentage' : (count/len(df))*100
            }
    
    return zeros

# %%
## 4. 병합 파일에서 결측치 찾기

processed_files = [f for f in os.listdir(DATA_OUTPUT_DIR) if f.startswith('gyeonggi_') and f.endswith('.csv')]
processed_files = sorted(processed_files)

print("결측치 찾기 시작")
print(f"파일: {len(processed_files)}개")

search_results = []

for i, filename in enumerate(processed_files, 1):
    month = filename.replace('gyeonggi_', '').replace('.csv', '')
    
    try:
        filepath = os.path.join(DATA_OUTPUT_DIR, filename)

        print(f"\n[{i:2d}/{len(processed_files)}] {month} 찾는 중...")
        
        # 파일 읽기
        df = pd.read_csv(filepath)
        
        # 실행
        missing_count = df.isnull().sum().sum()
        missing_by_col = {col: {'count': df[col].isnull().sum(), 
                                'percentage': round((df[col].isnull().sum() / len(df)) * 100, 4)}
                            for col in df.columns if df[col].isnull().sum() > 0}
        
        duplicate_count = df.duplicated().sum()
        negatives = df_negative(df)
        zeros = df_zero(df)
        
        # 결과 저장
        search_report = {
            'month': month,
            'data_shape': {'rows': len(df), 'columns': len(df.columns)},
            'results': {
                'missing_values': {'total_missing': missing_count, 'by_column': missing_by_col},
                'duplicates': {'total_duplicates': duplicate_count, 
                              'percentage': round((duplicate_count / len(df)) * 100, 4)},
                'negative_values': negatives,
                'zero_values': zeros
            }
        }
        
        search_results.append(search_report)
        
        del df
        gc.collect()
    
    except Exception as e:
        print(f"\n X {month} 오류: {str(e)[:40]}")

print("\n O 모든 월 찾기 완료")
# Out:
# 결측치 찾기 시작
# 파일: 45개
#
# [ 1/45] 202201 찾는 중...
#
# [ 2/45] 202202 찾는 중...
#
# [ 3/45] 202203 찾는 중...
#
# [ 4/45] 202204 찾는 중...
#
# [ 5/45] 202205 찾는 중...
#
# [ 6/45] 202206 찾는 중...
#
# [ 7/45] 202207 찾는 중...
#
# [ 8/45] 202208 찾는 중...
#
# [ 9/45] 202209 찾는 중...
#
# [10/45] 202210 찾는 중...
#
# [11/45] 202211 찾는 중...
#
# [12/45] 202212 찾는 중...
#
# [13/45] 202301 찾는 중...
#
# [14/45] 202302 찾는 중...
#
# [15/45] 202303 찾는 중...
#
# [16/45] 202304 찾는 중...
#
# [17/45] 202305 찾는 중...
#
# [18/45] 202306 찾는 중...
#
# [19/45] 202307 찾는 중...
#
# [20/45] 202308 찾는 중...
#
# [21/45] 202309 찾는 중...
#
# [22/45] 202310 찾는 중...
#
# [23/45] 202311 찾는 중...
#
# [24/45] 202312 찾는 중...
#
# [25/45] 202401 찾는 중...
#
# [26/45] 202402 찾는 중...
#
# [27/45] 202403 찾는 중...
#
# [28/45] 202404 찾는 중...
#
# [29/45] 202405 찾는 중...
#
# [30/45] 202406 찾는 중...
#
# [31/45] 202407 찾는 중...
#
# [32/45] 202408 찾는 중...
#
# [33/45] 202409 찾는 중...
#
# [34/45] 202410 찾는 중...
#
# [35/45] 202411 찾는 중...
#
# [36/45] 202412 찾는 중...
#
# [37/45] 202501 찾는 중...
#
# [38/45] 202502 찾는 중...
#
# [39/45] 202503 찾는 중...
#
# [40/45] 202504 찾는 중...
#
# [41/45] 202505 찾는 중...
#
# [42/45] 202506 찾는 중...
#
# [43/45] 202507 찾는 중...
#
# [44/45] 202508 찾는 중...
#
# [45/45] 202509 찾는 중...
#
#  O 모든 월 찾기 완료

# %%
# 결과 csv 파일로 저장
summary_data = []
for result in search_results:
    missing = result['results']['missing_values']
    duplicate = result['results']['duplicates']
    negative = result['results']['negative_values']
    zero = result['results']['zero_values']

    summary_data.append({
        'month': result['month'],
        'total_rows': result['data_shape']['rows'],
        'missing_count': missing['total_missing'],
        'duplicate_count': duplicate['total_duplicates'],
        'negative_count': sum(v['count'] for v in negative.values()) if negative else 0,
        'zero_count': sum(v['count'] for v in zero.values()) if zero else 0
    })

summary_df = pd.DataFrame(summary_data)
csv_output = os.path.join(ANALYSIS_OUTPUT_DIR, 'searching_summary.csv')
summary_df.to_csv(csv_output, index=False, encoding='utf-8-sig')

print("\n 결과 저장 완료")
# Out:
#  결과 저장 완료

# %%
# 결과 보기
summary_df = pd.read_csv(os.path.join(ANALYSIS_OUTPUT_DIR, 'searching_summary.csv'))
summary_df.head()
# Out:
#     month  total_rows  ...  negative_count  zero_count
# 0  202201    11479842  ...               0          89
# 1  202202    10191338  ...               0          76
# 2  202203    12106986  ...               0         115
# 3  202204    12500585  ...               0         148
# 4  202205    13218383  ...               0         153
#
# [5 rows x 6 columns]

# %%
# 0 값 제거

drop_target_month = summary_df[summary_df['zero_count'] > 0]['month'].tolist()
print(f'0값 제거 시작')
print(f'0값 제거 대상 월: {drop_target_month}')

# 디버깅용 변수
processed_count = 0

for i, month in enumerate(drop_target_month, 1):
    file_path = os.path.join(DATA_OUTPUT_DIR, f'gyeonggi_{month}.csv')
    print(f"[{i}/{len(drop_target_month)}] {month}...", end=" ")
    
    try:
        df = pd.read_csv(file_path)
        rows_before = len(df)
        
        # 0값 찾아서 제거 (수치형 컬럼만)
        for col in df.select_dtypes(include=[np.number]).columns:
            df = df[df[col] != 0]
            
        rows_after = len(df)
        removed_rows = rows_before - rows_after

        # 원본 파일에 덮어쓰기
        df.to_csv(file_path, index=False, encoding='utf-8-sig')
            
        print(f"완료 ({removed_rows:,}행 제거)")
        processed_count += 1
            
        del df
        gc.collect()

    except Exception as e:
        print(f"X 오류: {str(e)[:40]}")

print(f"처리 완료: {processed_count}개월")
# Out:
# 0값 제거 시작
# 0값 제거 대상 월: [202201, 202202, 202203, 202204, 202205, 202206, 202207, 202208, 202209, 202210, 202211, 202212, 202301, 202302, 202303, 202304, 202305, 202306, 202307, 202308, 202309, 202310, 202311, 202312, 202401, 202402, 202403, 202404, 202410]
# [1/29] 202201... 완료 (89행 제거)
# [2/29] 202202... 완료 (76행 제거)
# [3/29] 202203... 완료 (115행 제거)
# [4/29] 202204... 완료 (148행 제거)
# [5/29] 202205... 완료 (153행 제거)
# [6/29] 202206... 완료 (162행 제거)
# [7/29] 202207... 완료 (127행 제거)
# [8/29] 202208... 완료 (156행 제거)
# [9/29] 202209... 완료 (169행 제거)
# [10/29] 202210... 완료 (175행 제거)
# [11/29] 202211... 완료 (203행 제거)
# [12/29] 202212... 완료 (157행 제거)
# [13/29] 202301... 완료 (150행 제거)
# [14/29] 202302... 완료 (139행 제거)
# [15/29] 202303... 완료 (209행 제거)
# [16/29] 202304... 완료 (205행 제거)
# [17/29] 202305... 완료 (208행 제거)
# [18/29] 202306... 완료 (169행 제거)
# [19/29] 202307... 완료 (179행 제거)
# [20/29] 202308... 완료 (185행 제거)
# [21/29] 202309... 완료 (229행 제거)
# [22/29] 202310... 완료 (240행 제거)
# [23/29] 202311... 완료 (288행 제거)
# [24/29] 202312... 완료 (241행 제거)
# [25/29] 202401... 완료 (3,966행 제거)
# [26/29] 202402... 완료 (3,359행 제거)
# [27/29] 202403... 완료 (281행 제거)
# [28/29] 202404... 완료 (277행 제거)
# [29/29] 202410... 완료 (334행 제거)
# 처리 완료: 29개월

# %% [markdown]
# ## Step 4. 데이터 샘플링

# %%
# 최소 표본 크기 계산 후 샘플링 비율 산출

population_size = math.ceil(summary_df['total_rows'].sum()/len(summary_df)) # 모집단의 크기 (월별 데이터의 평균값)
margin_error = 0.05 # 5% 오차 한계
confidence_level = 0.95 # 95% 신뢰도

# 1. 신뢰도를 기반으로 z score를 정한다.
z_score = stats.norm.ppf((1 - confidence_level) / 2) # 신뢰도 95%일 때 1.96

# 2. p값을 0.5로 잡는다. 일반적으로 p값이 0.5일 때 표본이 최대 분산을 갖는다.
p = 0.5

# 3. 일반적으로 n = (z ** 2) * p * (1 - p) / e ** 2 과 같은 방법으로 구한다.
# 무한 모집단 가정 시 표본 크기
n = (z_score**2 * p * (1-p)) / (margin_error**2)

# 4. 유한모집단 수정 계수를 적용.

min_sample_size = math.ceil(n / (1 + ((n - 1) / population_size)))

# 5. 권장 샘플링 비율을 산출한다.
sampling_ratio = (n / population_size) * 100


# 결과 출력
print(f"  모집단의 크기 평균: {population_size}")
print(f"  최소 표본 크기: {min_sample_size}")
print(f"  최소 샘플링 비율: {sampling_ratio:.4f}%")
# Out:
#   모집단의 크기 평균: 12835278
#   최소 표본 크기: 385
#   최소 샘플링 비율: 0.0030%

# %%
# 계층화 샘플링 함수 정의

from sklearn.model_selection import train_test_split

# 샘플링 할 데이터
dtypes = {
    'card_tpbuz_cd': 'category',# 카드사 업종
    'admi_cty_no': 'int32',     # 지역구
    'ta_ymd': 'int32',          # 년월일
    'hour': 'int8',             # 시간대 
    'day': 'int8',              # 요일
    'age': 'int8',              # 연령 
    'sex': 'category',          # 성별
    'amt': 'int32',             # (전수화 보정이 적용된) 매출금액
    'cnt': 'int16'              # (전수화 보정이 적용된) 매출건수
}

# 에러 해결 완료.
def stratified_sampling(df, target_ratio=0.05, random_state=42):

    stratify = ['card_tpbuz_cd', 'admi_cty_no', 'ta_ymd']

    multi = df.duplicated(subset=stratify, keep=False)
    df_multi_groups = df[multi]
    df_single_groups = df[~multi]

    df_sampled = []

    if len(df_multi_groups) > 0 :
        indices = np.arange(len(df))
        try:
            sampled_idx, _ = train_test_split(
                indices, test_size=1 - target_ratio, random_state=random_state,
                stratify=df_multi_groups[stratify].values
            )
            df_sampled.append(df_multi_groups.iloc[sampled_idx])
        except:
            df_sampled.append(df_multi_groups.sample(frac=target_ratio, random_state=random_state))

    if len(df_single_groups) > 0:
        dsg_sample = df_single_groups.sample(frac=target_ratio, random_state=random_state)
        df_sampled.append(dsg_sample)

    if df_sampled:
        return pd.concat(df_sampled, ignore_index=True)
    else:
        return pd.DataFrame(columns=df.columns)

# %%
# 모든 월 일괄 샘플링

processed_files = sorted([f for f in os.listdir(DATA_OUTPUT_DIR) if f.startswith('gyeonggi_') and f.endswith('.csv')])

processed_count = 0
error_count = 0

for i, filename in enumerate(processed_files, 1):
    try:
        file_path = os.path.join(DATA_OUTPUT_DIR, filename)
        month = filename.replace('gyeonggi_', '').replace('.csv', '')
        
        print(f"[{i:2d}/{len(processed_files)}] {month}...", end=" ")

        # 파일 읽기
        df = pd.read_csv(file_path, dtype=dtypes)
        
        # 샘플링
        df_sampled = stratified_sampling(df, target_ratio=0.05)
        
        # 저장
        output_file = os.path.join(SAMPLING_OUTPUT_DIR, f'sampled_{month}.csv')
        df_sampled.to_csv(output_file, index=False, encoding='utf-8-sig')
        
        print(f"[{i:2d}/45] {month}: 완료, {len(df_sampled):,}행")
        
        processed_count += 1

        del df, df_sampled
        gc.collect()
    
    except Exception as e:
        print(f"X 오류: {str(e)[:40]}")
        error_count += 1

print(f"샘플링 완료: {processed_count}개월 처리, {error_count}개월 오류")
# Out:
# [ 1/45] 202201... [ 1/45] 202201: 완료, 573,988행
# [ 2/45] 202202... [ 2/45] 202202: 완료, 509,563행
# [ 3/45] 202203... [ 3/45] 202203: 완료, 605,343행
# [ 4/45] 202204... [ 4/45] 202204: 완료, 625,022행
# [ 5/45] 202205... [ 5/45] 202205: 완료, 660,912행
# [ 6/45] 202206... [ 6/45] 202206: 완료, 637,339행
# [ 7/45] 202207... [ 7/45] 202207: 완료, 648,788행
# [ 8/45] 202208... [ 8/45] 202208: 완료, 652,387행
# [ 9/45] 202209... [ 9/45] 202209: 완료, 627,989행
# [10/45] 202210... [10/45] 202210: 완료, 659,279행
# [11/45] 202211... [11/45] 202211: 완료, 633,005행
# [12/45] 202212... [12/45] 202212: 완료, 645,139행
# [13/45] 202301... [13/45] 202301: 완료, 615,025행
# [14/45] 202302... [14/45] 202302: 완료, 588,557행
# [15/45] 202303... [15/45] 202303: 완료, 670,194행
# [16/45] 202304... [16/45] 202304: 완료, 655,180행
# [17/45] 202305... [17/45] 202305: 완료, 686,004행
# [18/45] 202306... [18/45] 202306: 완료, 670,890행
# [19/45] 202307... [19/45] 202307: 완료, 678,276행
# [20/45] 202308... [20/45] 202308: 완료, 682,486행
# [21/45] 202309... [21/45] 202309: 완료, 655,327행
# [22/45] 202310... [22/45] 202310: 완료, 679,394행
# [23/45] 202311... [23/45] 202311: 완료, 649,050행
# [24/45] 202312... [24/45] 202312: 완료, 663,052행
# [25/45] 202401... [25/45] 202401: 완료, 648,592행
# [26/45] 202402... [26/45] 202402: 완료, 606,468행
# [27/45] 202403... [27/45] 202403: 완료, 680,334행
# [28/45] 202404... [28/45] 202404: 완료, 672,574행
# [29/45] 202405... [29/45] 202405: 완료, 692,793행
# [30/45] 202406... [30/45] 202406: 완료, 670,348행
# [31/45] 202407... [31/45] 202407: 완료, 685,044행
# [32/45] 202408... [32/45] 202408: 완료, 690,018행
# [33/45] 202409... [33/45] 202409: 완료, 651,208행
# [34/45] 202410... [34/45] 202410: 완료, 687,413행
# [35/45] 202411... [35/45] 202411: 완료, 651,785행
# [36/45] 202412... [36/45] 202412: 완료, 663,732행
# [37/45] 202501... [37/45] 202501: 완료, 578,607행
# [38/45] 202502... [38/45] 202502: 완료, 538,509행
# [39/45] 202503... [39/45] 202503: 완료, 616,619행
# [40/45] 202504... [40/45] 202504: 완료, 609,499행
# [41/45] 202505... [41/45] 202505: 완료, 635,883행
# [42/45] 202506... [42/45] 202506: 완료, 611,344행
# [43/45] 202507... [43/45] 202507: 완료, 647,126행
# [44/45] 202508... [44/45] 202508: 완료, 644,271행
# [45/45] 202509... [45/45] 202509: 완료, 624,397행
# 샘플링 완료: 45개월 처리, 0개월 오류

# %%
# 샘플 파일을 연도 별로 병합

# 1. 파일 목록
sampled_files = sorted([f for f in os.listdir(SAMPLING_OUTPUT_DIR) if f.startswith('sampled_') and f.endswith('.csv')])

print("샘플 파일 연도별 병합")
print(f"병합할 파일: {len(sampled_files)}개")

files_by_year = {}

for filename in sampled_files:
    month_str = filename.replace('sampled_', '').replace('.csv', '')
    years = month_str[:4]
    files_by_year.setdefault(years, []).append(filename)

for year in sorted(files_by_year.keys()):
    print(f"  {year}년: {len(files_by_year[year])}개월")

# 2. 병합
for year in sorted(files_by_year.keys()):
    print(f"\n【{year}년 병합】")

    merged_dfs = []

    for filename in sorted(files_by_year[year]):       
        file_path = os.path.join(SAMPLING_OUTPUT_DIR, filename)
        
        month_str = filename.replace('sampled_', '').replace('.csv', '')
        
        print(f"    병합 대상 : {month_str}...", end=" ")

        df = pd.read_csv(file_path)

        merged_dfs.append(df)

        print(f"    완료 :  {len(df):,}행")
        
        gc.collect()

    df_year = pd.concat(merged_dfs, ignore_index=True)

    output_file = os.path.join(SAMPLING_OUTPUT_DIR, f'sampled_{year}.csv')

    df_year.to_csv(output_file, index=False, encoding='utf-8-sig')

    print(f"완료! {len(df_year):,}행")

    print("【검증】")
    print(f"  행: {len(df_year):,}")
    print(f"  열: {len(df_year.columns)}")
    print(f"  중복행: {df_year.duplicated().sum()}")
    print(f"  결측치: {df_year.isnull().sum().sum()}")
    print(f"  파일 크기: {df_year.memory_usage(deep=True).sum() / 1024**3:.2f}GB")
    print(f"\n파일 저장: {output_file}")

    del df_year, merged_dfs
    gc.collect()

print("【병합 완료】")
# Out:
# 샘플 파일 연도별 병합
# 병합할 파일: 45개
#   2022년: 12개월
#   2023년: 12개월
#   2024년: 12개월
#   2025년: 9개월
#
# 【2022년 병합】
#     병합 대상 : 202201...     완료 :  573,988행
#     병합 대상 : 202202...     완료 :  509,563행
#     병합 대상 : 202203...     완료 :  605,343행
#     병합 대상 : 202204...     완료 :  625,022행
#     병합 대상 : 202205...     완료 :  660,912행
#     병합 대상 : 202206...     완료 :  637,339행
#     병합 대상 : 202207...     완료 :  648,788행
#     병합 대상 : 202208...     완료 :  652,387행
#     병합 대상 : 202209...     완료 :  627,989행
#     병합 대상 : 202210...     완료 :  659,279행
#     병합 대상 : 202211...     완료 :  633,005행
#     병합 대상 : 202212...     완료 :  645,139행
# 완료! 7,478,754행
# 【검증】
#   행: 7,478,754
#   열: 12
#   중복행: 0
#   결측치: 0
#   파일 크기: 2.39GB
#
# 파일 저장: ./data/external/sampled_2022.csv
#
# 【2023년 병합】
#     병합 대상 : 202301...     완료 :  615,025행
#     병합 대상 : 202302...     완료 :  588,557행
#     병합 대상 : 202303...     완료 :  670,194행
#     병합 대상 : 202304...     완료 :  655,180행
#     병합 대상 : 202305...     완료 :  686,004행
#     병합 대상 : 202306...     완료 :  670,890행
#     병합 대상 : 202307...     완료 :  678,276행
#     병합 대상 : 202308...     완료 :  682,486행
#     병합 대상 : 202309...     완료 :  655,327행
#     병합 대상 : 202310...     완료 :  679,394행
#     병합 대상 : 202311...     완료 :  649,050행
#     병합 대상 : 202312...     완료 :  663,052행
# 완료! 7,893,435행
# 【검증】
#   행: 7,893,435
#   열: 12
#   중복행: 0
#   결측치: 0
#   파일 크기: 2.52GB
#
# 파일 저장: ./data/external/sampled_2023.csv
#
# 【2024년 병합】
#     병합 대상 : 202401...     완료 :  648,592행
#     병합 대상 : 202402...     완료 :  606,468행
#     병합 대상 : 202403...     완료 :  680,334행
#     병합 대상 : 202404...     완료 :  672,574행
#     병합 대상 : 202405...     완료 :  692,793행
#     병합 대상 : 202406...     완료 :  670,348행
#     병합 대상 : 202407...     완료 :  685,044행
#     병합 대상 : 202408...     완료 :  690,018행
#     병합 대상 : 202409...     완료 :  651,208행
#     병합 대상 : 202410...     완료 :  687,413행
#     병합 대상 : 202411...     완료 :  651,785행
#     병합 대상 : 202412...     완료 :  663,732행
# 완료! 8,000,309행
# 【검증】
#   행: 8,000,309
#   열: 12
#   중복행: 0
#   결측치: 0
#   파일 크기: 2.55GB
#
# 파일 저장: ./data/external/sampled_2024.csv
#
# 【2025년 병합】
#     병합 대상 : 202501...     완료 :  578,607행
#     병합 대상 : 202502...     완료 :  538,509행
#     병합 대상 : 202503...     완료 :  616,619행
#     병합 대상 : 202504...     완료 :  609,499행
#     병합 대상 : 202505...     완료 :  635,883행
#     병합 대상 : 202506...     완료 :  611,344행
#     병합 대상 : 202507...     완료 :  647,126행
#     병합 대상 : 202508...     완료 :  644,271행
#     병합 대상 : 202509...     완료 :  624,397행
# 완료! 5,506,255행
# 【검증】
#   행: 5,506,255
#   열: 12
#   중복행: 0
#   결측치: 0
#   파일 크기: 1.76GB
#
# 파일 저장: ./data/external/sampled_2025.csv
# 【병합 완료】
